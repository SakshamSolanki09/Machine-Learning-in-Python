# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/data - data.csv")

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# checking the data is missing or not

# %%
data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# delete the columns which do not have required to predict the tumor like - id

# %%
data.drop(columns = data.columns[0],inplace = True)
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
question = data[data.columns[1:]]

# %%
question
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
answer = data[data.columns[0]]

# %%
balance = answer=="M"

# %% [markdown]
# checking that training data should be balanced

# %%
balance.sum() == len(balance)-balance.sum()
# Out:
# False

# %%
pos_class_data = data[data[data.columns[0]] == "M"]

# %%
pos_class_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 563         M        20.92         25.09          143.00     1347.0
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
neg_class_data = data[data[data.columns[0]] == "B"]

# %%
neg_class_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19          B       13.540         14.36           87.46      566.3
# 20          B       13.080         15.71           85.63      520.0
# 21          B        9.504         12.44           60.34      273.9
# 37          B       13.030         18.42           82.61      523.8
# 46          B        8.196         16.84           51.71      201.9
# ..        ...          ...           ...             ...        ...
# 558         B       14.590         22.68           96.39      657.1
# 559         B       11.510         23.93           74.52      403.5
# 560         B       14.050         27.15           91.38      600.4
# 561         B       11.200         29.37           70.67      386.0
# 568         B        7.760         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
training_data_len = round(len(data)*70/100)
cross_validation_data_len = round(len(data)*20/100)
testing_data_len = round(len(data)*10/100)
training_data_len + cross_validation_data_len + testing_data_len
# Out:
# 569

# %%
neg_class_train_data = neg_class_data.iloc[0:training_data_len//2,:]
pos_class_train_data = pos_class_data.iloc[0:training_data_len//2,:]
balance_train_data = pd.concat([neg_class_train_data,pos_class_train_data])

# %% [markdown]
# ![data-science-bayes-theorem-2.webp](data:image/webp;base64,...)

# %%
balance_train_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19          B       13.540         14.36           87.46      566.3
# 20          B       13.080         15.71           85.63      520.0
# 21          B        9.504         12.44           60.34      273.9
# 37          B       13.030         18.42           82.61      523.8
# 46          B        8.196         16.84           51.71      201.9
# ..        ...          ...           ...             ...        ...
# 499         M       20.590         21.24          137.80     1320.0
# 501         M       13.820         24.49           92.33      595.9
# 503         M       23.090         19.83          152.10     1682.0
# 509         M       15.460         23.95          103.80      731.3
# 512         M       13.400         20.52           88.64      556.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ![1_d0UCCIF10Soi7VQGxdVrWQ.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# sensitivity is also known as recall.
# fn is also known as type 1 error.
# fp is also known as type 2 error

# %%
cross_validation_data_len
# Out:
# 114

# %%
testing_data_len
# Out:
# 57

# %%
training_data_len
# Out:
# 398

# %%
training_data_len + cross_validation_data_len + testing_data_len
# Out:
# 569

# %%
neg_class_remain_data = neg_class_data.iloc[training_data_len//2:,:]
pos_class_remain_data = pos_class_data.iloc[training_data_len//2:,:]
remaining_data = pd.concat([neg_class_remain_data,pos_class_remain_data])

# %%
remaining_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 360         B        12.54         18.07           79.42      491.9
# 361         B        13.30         21.57           85.24      546.1
# 362         B        12.76         18.84           81.87      496.6
# 363         B        16.50         18.29          106.60      838.1
# 364         B        13.40         16.95           85.48      552.4
# ..        ...          ...           ...             ...        ...
# 563         M        20.92         25.09          143.00     1347.0
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
remaining_data = remaining_data.sample(frac = 1)

# %%
remaining_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 558         B       14.590         22.68           96.39      657.1
# 395         B       14.060         17.18           89.75      609.1
# 497         B       12.470         17.31           80.45      480.1
# 526         B       13.460         18.75           87.44      551.1
# 394         B       12.100         17.72           78.07      446.2
# ..        ...          ...           ...             ...        ...
# 568         B        7.760         24.54           47.92      181.0
# 398         B       11.060         14.83           70.31      378.2
# 518         B       12.880         18.22           84.45      493.1
# 387         B       13.880         16.16           88.37      596.6
# 391         B        8.734         16.84           55.27      234.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
cv_data = remaining_data.iloc[0:cross_validation_data_len]
test_data = remaining_data.iloc[cross_validation_data_len:]

# %%
sum(cv_data.iloc[:,0] != "M")
# Out:
# 107

# %%
sum(cv_data.iloc[:,0] == "M")
# Out:
# 7

# %%
from sklearn.naive_bayes import GaussianNB

# %%
obj = GaussianNB()

# %%
obj.fit(X=balance_train_data.iloc[:,1:],y=balance_train_data.iloc[:,0])
# Out:
# GaussianNB()

# %%
cv_pred = obj.predict(cv_data.iloc[:,1:])

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_true = cv_data.iloc[:,0],y_pred = cv_pred)
# Out:
# array([[103,   4],
#        [  1,   6]])

# %%
print(classification_report(y_true=cv_data.iloc[:,0],y_pred=cv_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.99      0.96      0.98       107
#            M       0.60      0.86      0.71         7
#
#     accuracy                           0.96       114
#    macro avg       0.80      0.91      0.84       114
# weighted avg       0.97      0.96      0.96       114
