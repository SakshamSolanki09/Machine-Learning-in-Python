# %% [markdown]
# Types of major neural networks:
#
#
# 1.   DNN
# 2.   RNN
# 3.   CNN
# 4.   Transformers

# %% [markdown]
# Types of Activation Functions:
#
#
# 1.   Linear
# 2.   Sigmoid
# 3.   Softmax
# 4.   ReLu (Rectified linear unit)
# 5.   TanH(Hyperbolic Tan)
# 6.   Leaky ReLU (Used in GANs)

# %% [markdown]
# Parts of nueral networks:
#
#
# 1. Input Layer(s)
# 2. Hidden Layer(s)
# 3. Output Layer(s)

# %%
loss function : Binary Cross Entropy

# %%
import pandas as pd
train_data = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
# Normalize Data
norm_data = (train_data-train_data.mean())/train_data.std()

# %%
norm_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       2.619288 -0.671500           -1.079639     1.361655        1.764152
# 1       2.539494 -0.573248           -0.761850     2.296540        3.230346
# 2       2.494610 -0.905436           -0.920744    -0.882436       -0.866931
# 3       2.489623 -0.928830           -1.159087    -0.524171       -0.480216
# 4       2.489623 -0.961581           -0.682402    -0.545731       -0.506313
# ...          ...       ...                 ...          ...             ...
# 16995  -2.342894  2.318197            1.859916    -0.195722       -0.344985
# 16996  -2.347881  2.369663            0.588757    -0.135170       -0.027072
# 16997  -2.362842  2.907715           -0.920744     0.015292       -0.019955
# 16998  -2.362842  2.889000           -0.761850     0.012998        0.029868
# 16999  -2.387778  2.299482            1.859916    -0.377837       -0.567998
#
# ...

# %%
# Seperate X and Y features
X_train = norm_data.iloc[:,1:]
Y_train = norm_data.iloc[:,0]

# %%
import tensorflow as tf
from keras.layers import Input,Dense,BatchNormalization
from keras.models import Sequential

# %%
# A function to Init Neural Net
def init_network():
  net = Sequential()
  net.add(Input(shape=(8,)))
  net.add(Dense(units=8,activation="relu"))
  net.add(Dense(units=8,activation = "relu"))
  net.add(Dense(units=1,activation = "relu"))
  net.compile(loss='mse')
  return net

# %%
net=init_network()
net.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 8)                 72
#
#  dense_9 (Dense)             (None, 8)                 72
#
#  dense_10 (Dense)            (None, 1)                 9
#
# ...
# Total params: 153
# Trainable params: 153
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train data with 500 batch size and 100 complete cycles over complete data(epochs)
net.fit(x = X_train,y = Y_train,batch_size=500,epochs=100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 2ms/step - loss: 1.0239
# Epoch 2/100
# 34/34 [==============================] - 0s 2ms/step - loss: 1.0010
# Epoch 3/100
# 34/34 [==============================] - 0s 2ms/step - loss: 1.0000
# Epoch 4/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.9999
# Epoch 5/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.9999
# Epoch 6/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.9999
# Epoch 7/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.9999
# Epoch 8/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.9999
# Epoch 9/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.9999
# Epoch 10/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.9999
# Epoch 11/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.9999
# Epoch 12/100
# ...

# %%
test_data = pd.read_csv("/content/sample_data/mnist_test.csv")

# %%
#Predict new data with the trained network
net.predict(x=X_train)
# Out:
# 532/532 [==============================] - 1s 1ms/step
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)
