# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dis = np.random.normal(loc = 40, scale = 4, size = 1000)
stddis = np.random.normal(loc = 0, scale = 1, size = 1000)

# %%
np.var(dis)
# Out:
# 17.00703632120997

# %%
np.var(dis)
# Out:
# 17.00703632120997

# %%
np.std(dis)
# Out:
# 4.1239588166238965

# %%
dis-np.mean(dis)
# Out:
# array([-2.18438130e+00, -3.76538193e+00,  8.08710020e+00,  2.19261767e+00,
#        -4.37555683e+00, -6.92136678e-01,  6.45151649e+00,  6.17981723e+00,
#        -4.34947020e+00, -3.92361812e+00,  1.64691900e+00,  1.85432290e+00,
#         2.93453273e+00,  4.77401345e+00,  1.95357515e+00,  1.50562272e+00,
#         6.22494606e+00, -2.65288041e-01, -4.71449778e+00, -2.59800822e+00,
#         4.86340649e+00, -1.66372947e+00,  6.66511992e+00,  1.29368907e+00,
#         5.00243778e+00,  4.58498314e+00, -2.38784272e+00, -7.27967697e+00,
#        -1.72946116e+00, -3.60477401e-01, -2.69037125e-01, -7.79565632e+00,
#         4.17060657e+00, -4.49015165e+00, -5.23891200e+00,  2.61799441e-01,
#        -7.55940800e+00,  3.00116108e+00,  4.49814028e-01,  6.32261355e+00,
#         8.08920705e-01, -1.46878751e+01, -1.15661075e+00,  1.53376081e+00,
#        -5.69078577e+00, -7.48518378e+00, -3.16995279e+00,  1.85593603e+00,
# ...
